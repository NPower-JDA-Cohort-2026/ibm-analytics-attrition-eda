# %%
# Importing required libraries
import pandas as pd

# %%
# Loading our attrition data into a pandas dataframe
df = pd.read_csv(
    "../data/raw/WA_Fn-UseC_-HR-Employee-Attrition.csv"
)

# Visualizing top 5 records
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Checking the shape of the dataset
print(f"The dataset contains {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# The dataset contains 1470 rows and 35 columns

# %%
# Checking data type and unique values from all columns
df_summary = pd.DataFrame({
    'Data Type': df.dtypes,
    'Unique': df.nunique()
})
df_summary
# Out:
#                          Data Type  Unique
# Age                          int64      43
# Attrition                      str       2
# BusinessTravel                 str       3
# DailyRate                    int64     886
# Department                     str       3
# DistanceFromHome             int64      29
# Education                    int64       5
# EducationField                 str       6
# EmployeeCount                int64       1
# EmployeeNumber               int64    1470
# EnvironmentSatisfaction      int64       4
# Gender                         str       2
# HourlyRate                   int64      71
# JobInvolvement               int64       4
# JobLevel                     int64       5
# JobRole                        str       9
# JobSatisfaction              int64       4
# MaritalStatus                  str       3
# MonthlyIncome                int64    1349
# MonthlyRate                  int64    1427
# NumCompaniesWorked           int64      10
# ...

# %%
# Checking some stats from all numerical columns 
df.describe().T # .T tansposes the output showing the collumns as rows
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
# Filtering just the columns with 'str' datatypes
df_summary[df_summary['Data Type'] == 'str']
# Out:
#                Data Type  Unique
# Attrition            str       2
# BusinessTravel       str       3
# Department           str       3
# EducationField       str       6
# Gender               str       2
# JobRole              str       9
# MaritalStatus        str       3
# Over18               str       1
# OverTime             str       2

# %% [markdown]
# #### **Conclusion**:
# - The exploratory analysis shows that the dataset contains **1,470** employee records across **35** variables, providing a broad view of employee demographics, compensation, job characteristics, satisfaction, and career experience. **The numerical variables reveal substantial variation** in factors such as **age**, **income**, **tenure**, **distance from home**, and **years of experience**. Satisfaction and workplace-related measures generally fall around the middle of their respective scales, while **categorical variables provide useful segmentation** by **department**, **job role**, **business travel**, **education field**, and **marital status**. Some constant variables, such as EmployeeCount, Over18, and StandardHours, provide little analytical value and may be excluded. Overall, the dataset provides a strong foundation for investigating employee characteristics, workplace factors, and potential drivers of attrition.
