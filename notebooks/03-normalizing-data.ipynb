# %%
import pandas as pd

df = pd.read_csv("../data/raw/WA_Fn-UseC_-HR-Employee-Attrition.csv")

df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
yn_map = {
    'No': 0,
    'Yes': 1
}
df['Attrition'] = df['Attrition'].map(yn_map)
print(df['Attrition'].unique())
# Out:
# [1 0]

# %%
#Maps yes/no into numeric values. Yes: 1, No: 0
df['OverTime'] = df['OverTime'].map(yn_map)
print(df['OverTime'].unique())
# Out:
# [1 0]

# %%
#Splits gender into the available categories
df = pd.get_dummies(df, 
        columns=['BusinessTravel',
        'Department',
        'EducationField',
        'Gender',
        'JobRole',
        'MaritalStatus'],
        dtype=int)
df_summary = pd.DataFrame({
    'Data Type': df.dtypes,
    'Unique': df.nunique()
})
df_summary
# Out:
#                                   Data Type  Unique
# Age                                   int64      43
# Attrition                             int64       2
# DailyRate                             int64     886
# DistanceFromHome                      int64      29
# Education                             int64       5
# EmployeeCount                         int64       1
# EmployeeNumber                        int64    1470
# EnvironmentSatisfaction               int64       4
# HourlyRate                            int64      71
# JobInvolvement                        int64       4
# JobLevel                              int64       5
# JobSatisfaction                       int64       4
# MonthlyIncome                         int64    1349
# MonthlyRate                           int64    1427
# NumCompaniesWorked                    int64      10
# Over18                                  str       1
# OverTime                              int64       2
# PercentSalaryHike                     int64      15
# PerformanceRating                     int64       2
# RelationshipSatisfaction              int64       4
# StandardHours                         int64       1
# StockOptionLevel                      int64       4
# TotalWorkingYears                     int64      40
# TrainingTimesLastYear                 int64       7
# WorkLifeBalance                       int64       4
# YearsAtCompany                        int64      37
# YearsInCurrentRole                    int64      19
# YearsSinceLastPromotion               int64      16
# YearsWithCurrManager                  int64      18
# BusinessTravel_Non-Travel             int64       2
# BusinessTravel_Travel_Frequently      int64       2
# BusinessTravel_Travel_Rarely          int64       2
# Department_Human Resources            int64       2
# Department_Research & Development     int64       2
# Department_Sales                      int64       2
# EducationField_Human Resources        int64       2
# EducationField_Life Sciences          int64       2
# EducationField_Marketing              int64       2
# EducationField_Medical                int64       2
# EducationField_Other                  int64       2
# EducationField_Technical Degree       int64       2
# Gender_Female                         int64       2
# Gender_Male                           int64       2
# JobRole_Healthcare Representative     int64       2
# JobRole_Human Resources               int64       2
# JobRole_Laboratory Technician         int64       2
# JobRole_Manager                       int64       2
# JobRole_Manufacturing Director        int64       2
# JobRole_Research Director             int64       2
# JobRole_Research Scientist            int64       2
# JobRole_Sales Executive               int64       2
# JobRole_Sales Representative          int64       2
# MaritalStatus_Divorced                int64       2
# MaritalStatus_Married                 int64       2
# MaritalStatus_Single                  int64       2

# %%
#There is only two numbers for peformance rating.
#Converting them to only one and zero seems like a logical approach
df['PerformanceRating'] = df['PerformanceRating'].map({3:0, 4:1})
df['PerformanceRating']
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    1
# 1468    0
# 1469    0
# Name: PerformanceRating, Length: 1470, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

numeric_cols = [
    'Age',
    'DailyRate',
    'DistanceFromHome',
    'HourlyRate',
    'MonthlyIncome',
    'MonthlyRate',
    'NumCompaniesWorked',
    'PercentSalaryHike',
    'TotalWorkingYears',
    'TrainingTimesLastYear',
    'YearsAtCompany',
    'YearsInCurrentRole',
    'YearsSinceLastPromotion',
    'YearsWithCurrManager'
]

scaler = StandardScaler()

df[numeric_cols] = scaler.fit_transform(df[numeric_cols])
# Age                               -0.758170 -0.101159  0.665354  2.526886
# Attrition                          0.000000  0.000000  0.000000  1.000000
# DailyRate                         -0.836662 -0.001204  0.878877  1.726730
# DistanceFromHome                  -0.887515 -0.270544  0.593216  2.444129
# Education                          2.000000  3.000000  4.000000  5.000000
# EnvironmentSatisfaction            2.000000  3.000000  4.000000  4.000000
# HourlyRate                        -0.880361  0.005356  0.878771  1.678377
# JobInvolvement                     2.000000  3.000000  3.000000  4.000000
# JobLevel                           1.000000  2.000000  3.000000  5.000000
# JobSatisfaction                    2.000000  3.000000  4.000000  4.000000
# MonthlyIncome                     -0.763209 -0.336552  0.398625  2.867626
# MonthlyRate                       -0.880644 -0.010906  0.864101  1.782888
# NumCompaniesWorked                -0.678049 -0.277594  0.523316  2.525591
# OverTime                           0.000000  0.000000  1.000000  1.000000
# PercentSalaryHike                 -0.877232 -0.330589  0.762698  2.675949
# PerformanceRating                  0.000000  0.000000  0.000000  1.000000
# RelationshipSatisfaction           2.000000  3.000000  4.000000  4.000000
# StockOptionLevel                   0.000000  1.000000  1.000000  3.000000
# TotalWorkingYears                 -0.678774 -0.164511  0.478316  3.692454
# TrainingTimesLastYear             -0.620189  0.155707  0.155707  2.483396
# WorkLifeBalance                    2.000000  3.000000  3.000000  4.000000
# YearsAtCompany                    -0.654454 -0.327893  0.325228  5.386914
# YearsInCurrentRole                -0.615492 -0.339394  0.764998  3.802074
# YearsSinceLastPromotion           -0.679146 -0.368715  0.252146  3.977310
# YearsWithCurrManager              -0.595227 -0.314873  0.806541  3.610079
# BusinessTravel_Non-Travel          0.000000  0.000000  0.000000  1.000000
# BusinessTravel_Travel_Frequently   0.000000  0.000000  0.000000  1.000000
# BusinessTravel_Travel_Rarely       0.000000  1.000000  1.000000  1.000000
# Department_Human Resources         0.000000  0.000000  0.000000  1.000000
# Department_Research & Development  0.000000  1.000000  1.000000  1.000000
# Department_Sales                   0.000000  0.000000  1.000000  1.000000
# EducationField_Human Resources     0.000000  0.000000  0.000000  1.000000
# EducationField_Life Sciences       0.000000  0.000000  1.000000  1.000000
# EducationField_Marketing           0.000000  0.000000  0.000000  1.000000
# EducationField_Medical             0.000000  0.000000  1.000000  1.000000
# EducationField_Other               0.000000  0.000000  0.000000  1.000000
# EducationField_Technical Degree    0.000000  0.000000  0.000000  1.000000
# Gender_Female                      0.000000  0.000000  1.000000  1.000000
# Gender_Male                        0.000000  1.000000  1.000000  1.000000
# JobRole_Healthcare Representative  0.000000  0.000000  0.000000  1.000000
# JobRole_Human Resources            0.000000  0.000000  0.000000  1.000000
# JobRole_Laboratory Technician      0.000000  0.000000  0.000000  1.000000
# JobRole_Manager                    0.000000  0.000000  0.000000  1.000000
# JobRole_Manufacturing Director     0.000000  0.000000  0.000000  1.000000
# JobRole_Research Director          0.000000  0.000000  0.000000  1.000000
# JobRole_Research Scientist         0.000000  0.000000  0.000000  1.000000
# JobRole_Sales Executive            0.000000  0.000000  0.000000  1.000000
# JobRole_Sales Representative       0.000000  0.000000  0.000000  1.000000
# MaritalStatus_Divorced             0.000000  0.000000  0.000000  1.000000
# MaritalStatus_Married              0.000000  0.000000  1.000000  1.000000
# MaritalStatus_Single               0.000000  0.000000  1.000000  1.000000

# %%
#Removed columns that had no predictive variablity (i.e. only one unique value) and employee number
df = df.drop(columns=['EmployeeNumber', 'EmployeeCount', 'Over18', 'StandardHours'])
