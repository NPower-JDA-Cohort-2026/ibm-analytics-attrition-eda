# %%
# Employee Attrition Analysis

This notebook will be used to analyze employee attrition patterns in the IBM HR Analytics dataset.

## Objectives
- Explore employee attrition patterns.
- Identify factors associated with employee attrition.
- Create visualizations to support the analysis.
- Summarize key business insights.

**Contributor:** Moustafa Ismail
